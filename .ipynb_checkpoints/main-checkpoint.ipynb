# %%
import pandas as pd
import json
from flask import Flask, render_template

# %%
import requests
url = "https://ero.betfair.com/www/sports/exchange/readonly/v1/bymarket?_ak=nzIFcwyWhrlwYMrh&currencyCode=GBP&locale=en_GB&marketIds=1.128151441&rollupLimit=10&rollupModel=STAKE&types=MARKET_STATE,RUNNER_STATE,RUNNER_EXCHANGE_PRICES_BEST,RUNNER_DESCRIPTION"
url2 = "https://ero.betfair.com/www/sports/exchange/readonly/v1/bymarket?_ak=nzIFcwyWhrlwYMrh&alt=json&currencyCode=GBP&locale=en_GB&marketIds=1.170917778,1.128988348&rollupLimit=10&rollupModel=STAKE&types=MARKET_STATE,RUNNER_STATE,RUNNER_EXCHANGE_PRICES_BEST"

payload = {}
headers = {
  'Connection': 'keep-alive',
  'Accept': 'application/json, text/plain, */*',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36',
  'DNT': '1',
  'Origin': 'https://www.betfair.com',
  'Sec-Fetch-Site': 'same-site',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Dest': 'empty',
  'Referer': 'https://www.betfair.com/',
  'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
  'Cookie': '__cfduid=d3013254245c8d86c0aae9e7a0fe0cd661604447496; wsid=8246db31-1e2f-11eb-b7f4-fa163ea4ad04; vid=fa6d8bae-3b04-4a6b-b4f4-76df1b3615de; bfsd=ts=1604447498682|st=p; storageSSC=lsSSC%3D1; xsrftoken=a0a7a690-1e2f-11eb-9f1a-fa163e8a430a; PI=3013; StickyTags=rfr=3013; TrackingTags=; pi=partner3013; rfr=3013; exp=ex; language=en_GB; betexPtk=betexCurrency%3DGBP~betexTimeZone%3DEurope%2FLondon~betexRegion%3Dundefined~betexLocale%3Den_GB; betexPtkSess=betexCurrencySessionCookie%3DGBP~betexLocaleSessionCookie%3Den_GB~betexRegionSessionCookie%3DGBR'

}

response = requests.request("GET", url, headers=headers, data = payload)

# %%
#unpack the data from the json - odds snapshot
df=pd.json_normalize(json.loads(response.text),record_path=["eventTypes","eventNodes","marketNodes","runners"],meta=["eventTypes"], errors="ignore")

# %%
#unpack the timestamp and metadata
df2=df.eventTypes.apply(pd.Series).eventNodes.apply(pd.Series)[0].apply(pd.Series).marketNodes.apply(pd.Series)[0].apply(pd.Series).state.apply(pd.Series)

# %%
#combine metadata with odds data
final_df=pd.concat([df,df2.reindex(df.index)],axis=1)

# %%
final_df
# Out:
#      selectionId  handicap    description.runnerName  state.sortPriority  \
# 0        6816445       0.0                 Joe Biden                   1
# 1       10874213       0.0              Donald Trump                   2
# 2        4296631       0.0                Mike Pence                   3
# 3        3110151       0.0                 Tim Kaine                   4
# 4        7438258       0.0               Cory Booker                   5
# ..           ...       ...                       ...                 ...
# 119     30274172       0.0              Jo Jorgensen                 120
# 120     35709762       0.0             Howie Hawkins                 121
# 121     36024818       0.0                Mark Esper                 122
# 122     36502219       0.0             Patrick Leahy                 123
# 123     20036602       0.0  Alexandria Ocasio-Cortez                 124
#
#      state.lastPriceTraded  state.totalMatched state.status  \
# 0                     1.12                 0.0       ACTIVE
# 1                     9.20                 0.0       ACTIVE
# 2                  1000.00                 0.0       ACTIVE
# 3                  1000.00                 0.0       ACTIVE
# 4                  1000.00                 0.0       ACTIVE
# ..                     ...                 ...          ...
# 119                1000.00                 0.0       ACTIVE
# 120                1000.00                 0.0       ACTIVE
# 121                1000.00                 0.0       ACTIVE
# 122                1000.00                 0.0       ACTIVE
# 123                    NaN                 NaN      REMOVED
#
#                               exchange.availableToBack  \
# 0    [{'price': 1.12, 'size': 61436.45}, {'price': ...
# 1    [{'price': 9.2, 'size': 124.71}, {'price': 9.0...
# 2    [{'price': 1000.0, 'size': 9424.71}, {'price':...
# 3    [{'price': 1000.0, 'size': 11746.76}, {'price'...
# 4    [{'price': 1000.0, 'size': 9028.14}, {'price':...
# ..                                                 ...
# 119  [{'price': 1000.0, 'size': 9257.64}, {'price':...
# 120  [{'price': 1000.0, 'size': 9424.36}, {'price':...
# 121  [{'price': 1000.0, 'size': 9471.79}, {'price':...
# 122  [{'price': 1000.0, 'size': 10539.37}, {'price'...
# 123                                                NaN
#
#                                exchange.availableToLay  \
# 0    [{'price': 1.13, 'size': 46208.91}, {'price': ...
# 1    [{'price': 9.4, 'size': 156.73}, {'price': 9.6...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
#             state.removalDate  ... numberOfWinners  numberOfRunners  \
# 0                         NaN  ...               1              124
# 1                         NaN  ...               1              124
# 2                         NaN  ...               1              124
# 3                         NaN  ...               1              124
# 4                         NaN  ...               1              124
# ..                        ...  ...             ...              ...
# 119                       NaN  ...               1              124
# 120                       NaN  ...               1              124
# 121                       NaN  ...               1              124
# 122                       NaN  ...               1              124
# 123  2019-02-07T17:48:16.000Z  ...               1              124
#
#      numberOfActiveRunners             lastMatchTime  totalMatched  \
# 0                      123  2020-11-05T00:26:05.657Z  4.722070e+08
# 1                      123  2020-11-05T00:26:05.657Z  4.722070e+08
# 2                      123  2020-11-05T00:26:05.657Z  4.722070e+08
# 3                      123  2020-11-05T00:26:05.657Z  4.722070e+08
# 4                      123  2020-11-05T00:26:05.657Z  4.722070e+08
# ..                     ...                       ...           ...
# 119                    123  2020-11-05T00:26:05.657Z  4.722070e+08
# 120                    123  2020-11-05T00:26:05.657Z  4.722070e+08
# 121                    123  2020-11-05T00:26:05.657Z  4.722070e+08
# 122                    123  2020-11-05T00:26:05.657Z  4.722070e+08
# 123                    123  2020-11-05T00:26:05.657Z  4.722070e+08
#
#      totalAvailable  crossMatching  runnersVoidable     version  status
# 0      3.669343e+07          False            False  3450999831    OPEN
# 1      3.669343e+07          False            False  3450999831    OPEN
# 2      3.669343e+07          False            False  3450999831    OPEN
# 3      3.669343e+07          False            False  3450999831    OPEN
# 4      3.669343e+07          False            False  3450999831    OPEN
# ..              ...            ...              ...         ...     ...
# 119    3.669343e+07          False            False  3450999831    OPEN
# 120    3.669343e+07          False            False  3450999831    OPEN
# 121    3.669343e+07          False            False  3450999831    OPEN
# 122    3.669343e+07          False            False  3450999831    OPEN
# 123    3.669343e+07          False            False  3450999831    OPEN
#
# [124 rows x 25 columns]

# %%
final_df.to_csv("data.csv",mode='a',header=False)

# %%
app = Flask(__name__)


@app.route("/") 
def home(): 
	df = plot_data()
	return render_template('index.html',  tables=[df.to_html(classes='data')], titles=df.columns.values)

# %%
import plotly.express as px

# %%
def plot_data():
    df_to_plot=pd.read_csv("data.csv")
    df_to_plot=df_to_plot[(df_to_plot['description.runnerName']=='Joe Biden')|(df_to_plot['description.runnerName']=='Donald Trump')]
    pivot = df_to_plot.pivot_table(index='lastMatchTime', columns='description.runnerName' ,values ='state.lastPriceTraded')
    return pivot

# %%
# Out:
#      Unnamed: 0  selectionId  handicap    description.runnerName  \
# 0             0      6816445       0.0                 Joe Biden
# 1             1     10874213       0.0              Donald Trump
# 2             2      4296631       0.0                Mike Pence
# 3             3      3110151       0.0                 Tim Kaine
# 4             4      7438258       0.0               Cory Booker
# ..          ...          ...       ...                       ...
# 863         119     30274172       0.0              Jo Jorgensen
# 864         120     35709762       0.0             Howie Hawkins
# 865         121     36024818       0.0                Mark Esper
# 866         122     36502219       0.0             Patrick Leahy
# 867         123     20036602       0.0  Alexandria Ocasio-Cortez
#
#      state.sortPriority  state.lastPriceTraded  state.totalMatched  \
# 0                     1                   1.13                 0.0
# 1                     2                   9.20                 0.0
# 2                     3                1000.00                 0.0
# 3                     4                1000.00                 0.0
# 4                     5                1000.00                 0.0
# ..                  ...                    ...                 ...
# 863                 120                1000.00                 0.0
# 864                 121                1000.00                 0.0
# 865                 122                1000.00                 0.0
# 866                 123                1000.00                 0.0
# 867                 124                    NaN                 NaN
#
#     state.status                           exchange.availableToBack  \
# 0         ACTIVE  [{'price': 1.12, 'size': 66287.04}, {'price': ...
# 1         ACTIVE  [{'price': 9.0, 'size': 1225.91}, {'price': 8....
# 2         ACTIVE  [{'price': 1000.0, 'size': 9424.71}, {'price':...
# 3         ACTIVE  [{'price': 1000.0, 'size': 11746.76}, {'price'...
# 4         ACTIVE  [{'price': 1000.0, 'size': 9028.14}, {'price':...
# ..           ...                                                ...
# 863       ACTIVE  [{'price': 1000.0, 'size': 9257.64}, {'price':...
# 864       ACTIVE  [{'price': 1000.0, 'size': 9424.36}, {'price':...
# 865       ACTIVE  [{'price': 1000.0, 'size': 9471.79}, {'price':...
# 866       ACTIVE  [{'price': 1000.0, 'size': 10539.37}, {'price'...
# 867      REMOVED                                                NaN
#
#                                exchange.availableToLay  ... numberOfWinners  \
# 0    [{'price': 1.13, 'size': 46912.21}, {'price': ...  ...               1
# 1    [{'price': 9.2, 'size': 523.36}, {'price': 9.4...  ...               1
# 2                                                  NaN  ...               1
# 3                                                  NaN  ...               1
# 4                                                  NaN  ...               1
# ..                                                 ...  ...             ...
# 863                                                NaN  ...               1
# 864                                                NaN  ...               1
# 865                                                NaN  ...               1
# 866                                                NaN  ...               1
# 867                                                NaN  ...               1
#
#     numberOfRunners  numberOfActiveRunners             lastMatchTime  \
# 0               124                    123  2020-11-05T00:24:00.471Z
# 1               124                    123  2020-11-05T00:24:00.471Z
# 2               124                    123  2020-11-05T00:24:00.471Z
# 3               124                    123  2020-11-05T00:24:00.471Z
# 4               124                    123  2020-11-05T00:24:00.471Z
# ..              ...                    ...                       ...
# 863             124                    123  2020-11-05T00:53:36.018Z
# 864             124                    123  2020-11-05T00:53:36.018Z
# 865             124                    123  2020-11-05T00:53:36.018Z
# 866             124                    123  2020-11-05T00:53:36.018Z
# 867             124                    123  2020-11-05T00:53:36.018Z
#
#      totalMatched  totalAvailable  crossMatching  runnersVoidable     version  \
# 0    4.721772e+08    3.670805e+07          False            False  3450999831
# 1    4.721772e+08    3.670805e+07          False            False  3450999831
# 2    4.721772e+08    3.670805e+07          False            False  3450999831
# 3    4.721772e+08    3.670805e+07          False            False  3450999831
# 4    4.721772e+08    3.670805e+07          False            False  3450999831
# ..            ...             ...            ...              ...         ...
# 863  4.726064e+08    3.678493e+07          False            False  3450999831
# 864  4.726064e+08    3.678493e+07          False            False  3450999831
# 865  4.726064e+08    3.678493e+07          False            False  3450999831
# 866  4.726064e+08    3.678493e+07          False            False  3450999831
# 867  4.726064e+08    3.678493e+07          False            False  3450999831
#
#     status
# 0     OPEN
# 1     OPEN
# 2     OPEN
# 3     OPEN
# 4     OPEN
# ..     ...
# 863   OPEN
# 864   OPEN
# 865   OPEN
# 866   OPEN
# 867   OPEN
#
# [868 rows x 26 columns]

# %%
# Out:
# description.runnerName    Donald Trump  Joe Biden
# lastMatchTime
# 2020-11-05T00:24:00.471Z           9.2       1.13
# 2020-11-05T00:26:05.657Z           9.2       1.12
# 2020-11-05T00:45:27.285Z           8.0       1.14
# 2020-11-05T00:47:58.624Z           8.0       1.14
# 2020-11-05T00:48:16.452Z           8.2       1.15
# 2020-11-05T00:50:02.838Z           8.2       1.14
# 2020-11-05T00:53:36.018Z           8.8       1.13
